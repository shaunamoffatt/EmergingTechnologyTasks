# %% [markdown]
# # KNN for the Iris DataSet using scikit-learn
#
# K Nearest Neighbor(kNN) algorithm is a similarity-based learning method to correctly classify a query point based on its proximity to  *k* number of nearest neighbors. The KNeighborsClassifier function doesn't train the model but stores all the training data into memory. When given a query point, the *k* number of nearest neighbors vote on what the unknown query point might be classified as based on its own class.[1]
#
# ![image.png](attachment:image.png)
#
# [1] https://towardsdatascience.com/knn-visualization-in-just-13-lines-of-code-32820d72c6b6
# (image from the same article)

# %% [markdown]
# #### Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#plotting paralled_coordinate graph
from pandas.plotting import parallel_coordinates
import seaborn as sns
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
#from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Importing the Iris Dataset
#
# The iris data set contains a sample of 150 iris' of 3 different species of the iris flower; 'setosa', 'versicolor' and  'virginica'. It contains features on the petal length and width and sepal length and width for each of the samples.[2]
#
# [2] https://www.kaggle.com/arshid/iris-flower-dataset?select=IRIS.csv

# %%
#loading in the dataset [2]
iris = pd.read_csv('dataset/iris.csv')
#Show the first 10 rows in the dataset
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %% [markdown]
# ## Data Visualization of Iris Data

# %%
#return the number of rows and colums
#display the info on the dataset
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Group the species together

# %%
iris.groupby('species').size()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# ####  remarks
# the data is balanced and the labels of species are evenly split
#
# ### Parallel Coordinates

# %%
plt.style.use('seaborn-darkgrid')
plt.style.use('seaborn-poster')
#https://coderzcolumn.com/tutorials/data-science/how-to-plot-parallel-coordinates-plot-in-python-matplotlib-plotly
palette = color=["lime", "tomato","dodgerblue"]
pd.plotting.parallel_coordinates(
    iris, "species", color=palette, alpha=0.15);

#Change Title, legends and X and Y labels
plt.title("IRIS Flowers Parallel Coorinates Plot")
plt.xlabel('Features', fontsize=20)
plt.ylabel('Features values', fontsize=20)
plt.legend(loc=1, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")

plt.show()

# %% [markdown]
# ### Comparing different categories

# %%
#https://jss367.github.io/Exploring-Iris-Dataset.html
hue_order = iris['species'].unique()[::-1]
#palette = sns.color_palette('bright')
sns.pairplot(iris, hue="species", hue_order=hue_order, palette=palette, markers=["o", "s", "D"], diag_kind='kde');

# %% [markdown]
# Petal width and length look to be a good variable to distinuish the different species from one another. Sepal is a good indicator for distinguishing iris-setosa from iris-versicolor and iris-virginica. Iris-setosa seems to have the more unique features whereas iris-virginica and iris-versicolor being more similar (apart from iris-versicolor being slightly larger in petal lendgth and width.
#
# The dataset is fairly linear and will suit being trained with the kNN algorithm

# %% [markdown]
# ### Dividing the data
#
# We will split the data into 2 arrays. One that contains the features decribing the petal and sepal (column 0-3) and the other into the names of the species(column 4).

# %%
#https://realpython.com/pandas-python-explore-dataset/
#set the feature to be the names of the columns 
features = list(iris.axes[1])
#remove the 'species' name
features.pop()
features
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
# Split the data into 2 arrays
# X : features
# Y : labels
X = iris[features].values
y = iris['species'].values

# %% [markdown]
# ### Label encoding
#
# KNeighborsClassifier does not accept string labels for the species so we need to convert them into numbers using LabelEncoder. With the numbers corresponding as such:
#
#     0 : Iris-setosa
#     1 : Iris-versicolor
#     2 : Irish-virginica
# []https://www.kaggle.com/skalskip/iris-data-visualization-and-knn-classification

# %%
#label encoding 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %% [markdown]
# ### Splitting the data into Training and Test sets
#
# We will spilt our data into 80% training data and 20% testing data.[]
#
#     test_size = 0.2
#
# We will stratify our data so that we get and eve amount of each iris species in our testing and training data.
#
#     stratify = y
#
# [] https://stackabuse.com/k-nearest-neighbors-algorithm-in-python-and-scikit-learn/

# %%
#use the train_split_test function to split the data
#test_size 0.2 splits it into a 80:20 split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, random_state = 0, stratify=y)

# %%
#size of training and test datasets
print("Training set size: ",X_train.shape)
print("Test set size: ",X_test.shape)
# Out:
# Training set size:  (120, 4)
# Test set size:  (30, 4)

# %%
# plotting gotten from https://github.com/vsuriya93/coding-machine-learning/blob/master/decision-tree/script.py
def plotData(X_train,y_train):
    SIZE=50
    for index,row in enumerate(X_train):
        if y_train[index]==0:
            c=palette[2]
            marker='D'
            q=plt.scatter(X_train[index,0],X_train[index,1],c=c,marker=marker,s=SIZE)
        elif y_train[index]==1:
            c=palette[0]
            marker='o'
            w=plt.scatter(X_train[index,0],X_train[index,1],c=c,marker=marker,s=SIZE)
        else:
            c=palette[1]
            marker='s'
            e=plt.scatter(X_train[index,0],X_train[index,1],c=c,marker=marker,s=SIZE)
    

    plt.legend((q,w,e),('setosa','virginica','versicolor'),scatterpoints=1)

# %%
#Plot the training data
plotData(X_train,y_train)

# %% [markdown]
# ## k-Nearest Neighbors

# %% [markdown]
# ### Accuracy

# %%
def kNNModelTraining(_n_neighbors, _weights):
    knn_model = KNeighborsClassifier(n_neighbors = _n_neighbors, weights=_weights)
    #fit the model with the training data 
    knn_model.fit(X_train, y_train)
    return knn_model

# %%
### Make a model and predict the test data
def kNNAccuracy(_n_neighbors, _weights):
    knn_model = kNNModelTraining(_n_neighbors, _weights)
    y_predict = knn_model.predict(X_test)
    
    #https://www.youtube.com/watch?v=-wadcBarRRk&ab_channel=JAcademy&fbclid=IwAR08BKve3MKekpagBV8c8JiO4uReQONmyYYZcIxlRLj-Ky08AgXs6mo4WxI
    acc = accuracy_score(y_test, y_predict)
    print("Accuracy of {:.2f} %".format(acc*100))#
  
    return y_predict

# %% [markdown]
# ### Confusion Matrices

# %%
# Display the confusion matrix as a heat map
# https://medium.com/@avulurivenkatasaireddy/k-nearest-neighbors-and-implementation-on-iris-data-set-f5817dd33711
def confusionM(y_predict):
    confusion_m = confusion_matrix(y_test, y_predict)
    confusion_m

    cm = pd.DataFrame( data = confusion_m ,
                  index = hue_order, columns =  hue_order )
    
    sns.heatmap(cm, annot=True)
    plt.title('Accuracy :{0:.3f}'.format(accuracy_score(y_test, y_predict)))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# ## Results
#
# ### Default KNN Classifier k = 5 , weights= 'uniform'

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# Train and predict on the Default KNN Classifier 
# K=5 and weights = 'uniform' are the default values for these parameters
print("Default KNN Classifer, k= 5 and weight= 'uniform'")
y_predict1 = kNNAccuracy(5, 'uniform')
confusionM(y_predict1)
# Out:
# Default KNN Classifer, k= 5 and weight= 'uniform'
# Accuracy of 100.00 %

# %% [markdown]
# ### Model trained using custom parameters k = 13, weights='distance'

# %%
# Now train the model again custom parameters
# When distance is used for the weights parameter, the default metric will be 'Minkowski'.
# The output from the Minkowski algorithm will depend on the 'P' hyper-parameter
# When P is 1, Minkowski will be Manhattan distance, when P is 2 (Default) it will measure as euclidean distance
print("\nCustom parameters: k = 13, weights = 'distance'")
y_predict2 = kNNAccuracy(13, 'distance')
confusionM(y_predict2)
# Out:
# Custom parameters: k = 13, weights = 'distance'
# Accuracy of 100.00 %

# %% [markdown]
# ### Model trained on poor hyper-parameters k = 63

# %%
# Example of a model trained on poor hyper-parameters
print("\nPoor hyper-parameters, k = 63, weights = 'uniform'")
y_predict3 = kNNAccuracy(63, 'uniform')
confusionM(y_predict3)
# Out:
# Poor hyper-parameters, k = 63, weights = 'uniform'
# Accuracy of 86.67 %

# %% [markdown]
# ## Evaluating the importance of k value

# %%
# https://www.ritchieng.com/machine-learning-k-nearest-neighbors-knn/
# set the range from K=1 to K=80 and record testing accuracy
k_range = range(1, 100)

scores = []

# Loop through and append the score to scores
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(accuracy_score(y_test, y_pred))

# plot the relationship between K and testing accuracy
plt.plot(k_range, scores)
plt.title("Accuracy of Predictions Depending on k value")
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
plt.show()

# %% [markdown]
# ### Remarks
#
# We can see0 that choosing the number of neighbours is important in getting an accurate prediction of our test data sample. For the iris data set, when using a uniform weighting, k values between ~3 and ~23 give a good accuracy. Too small of a k-value doesnt give enough to choose from, and too large and its impossible for our sample size.
#
# ## Custom Predictions using an accurate kNN model
#
# We can make our own predictions on iris' using an accurately trained kNN model (in this case using a k= 13 and weight = 'distance')

# %%
# Custom function for predicting the iris type of a flower by the features measured
# Using a k of 13 and weight using distance, as it appears to give an accurate estimation
def predictIris(sepal_length, sepal_width, petal_length, petal_width):
    knn_model = kNNModelTraining(13, 'distance')
    y_pred = knn_model.predict([[sepal_length,sepal_width,petal_length,petal_width]])
    if(y_pred[0] == 0):
        return "Iris-Setosa"
    elif(y_pred[0] == 1):
        return "Iris-Versicolor"
    elif(y_pred[0] == 2) :
        return "Iris-Virginica"
    else:
        return "ERROR"

# %% [markdown]
# ### Sample data taken from the iris.csv file
#
# #### Iris-setosa

# %%
#5.1,3.5,1.4,0.2,Iris-setosa
predictIris(5.1,3.5,1.4,0.2)
# Out:
# 'Iris-Setosa'

# %% [markdown]
# #### Iris-Virginica

# %%
#6.9,3.1,5.1,2.3,Iris-virginica
predictIris(6.9,3.1,5.1,2.3)
# Out:
# 'Iris-Virginica'

# %% [markdown]
# #### Iris-Versicolor

# %%
# 6.1,2.9,4.7,1.4,Iris-versicolor
predictIris(6.1,2.9,4.7,1.4)
# Out:
# 'Iris-Versicolor'

# %% [markdown]
# ## Conclusion
#
# With a linear, evenly distributed catagorized dataset, kNN algorithm can be used  to simply and quickly train the dataset and make accurate predictions when given an ideal number of neighbors k and proper weight.

# %% [markdown]
# END
